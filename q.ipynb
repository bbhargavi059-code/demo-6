# %%
# using python
# i like python
# * l*k* python*n

s=str(input("enter a sentence"))
v="aeiouAEIOU"
res=''
for i in s:
    if i in v:
        res+="*"
    else:
        res+=i
print(res)
# Out:
# enter a sentence  i like python
#  * l*k* pyth*n

# %%
# check the sting is palindrom or not
a=(input("the sring is palindom"))
if a==a[::1]:
    print("palindom")
else:
    print("not palindom")
# Out:
# the sring is palindom 12
# palindom

# %%
# 1 to 20
# 15 jackpot number
#10
# choose the higher number
#19
# choose the lower number
#15
# your attampt is 3 times

import random
jackpot=random.randint(1,20)
jackpot = 15

guess = int(input("Enter a number: "))

if guess == jackpot:
    
    print("You Won")
elif guess < jackpot:
    print("Choose Higher Number")
else:
    print("Choose Lower Number")

# %%
import random
jackpot=random.randint(1,20)
user_num=int(input("Enter a number:"))
c=1
while jackpot!=user_num:
    if user_num<jackpot:
        print(" chose the higher !!!!")
        print(" chose the lower !!!!")
    user_num=int(input("Enter a number: "))
    c+=1
else:
    print("you own the game jackpot num is",user_num)
    print("your attempt",c)
